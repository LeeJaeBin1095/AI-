# %%
#0.2 ~0.22
a = [10,40]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 200
#0.31
a = [16,20]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 201
#1.0~1.1
a = [102, 70]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 202
#1.1~1.2
a = [80,39,21,140,56]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 203
#1.2~1.3
a = [12,62,122]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 204
#1.4~1.5
a = [53,81,23]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 205
#1.5~1.6
a = [82,121,151,50,130,14,150]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 206   
#1.6~1.7
a = [120,152,153,131]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 207   
#1.7~1.8
a = [17,60,110]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 208
# 1.8
a = [100,71]
for i in a : 
    df_org.loc[df_org['통관지세관부호'] == i , '통관지세관부호'] = 209

# %%
#0.37
a = ['PR5UFJ','PAVJZL']  
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 10
#0.5
a = ['24BG4R','TQ18AK','O04TIW']  
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 11
# 0.7   
a = ['QJ0YGH','6TFEP5'] 
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 12
#0.95~1.1
a = ['ID7FLR','QKUSM1','5SZ7FO','OJ6WM3','2ADDNP','26O9QU','6AXUNR','883CMC','VI9G4M']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 13
#1.1~1.2
a = ['TOO0OK','8Z7M3O','HGT4IX','VSYNVB','C54WLZ','6VXR7R','K35446','XK2HKR']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 14
#1.2~1.25
a = ['D3H0A4','HN5E27','Q8TBEO','QSV8RY','KTBTZT','RDEAWL',' ME9TG4','HB62YN','5HIQAV','A41WVG']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 15
#1.25~1.3
a = ['6EM00W','XIKL72','L67RFP','YBNP69','6MSSDI','L2ILSN','FK5XHP','98GCBT','M7SEXF']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 16
#1.34~1.38
a = ['A9QWI8','90DF54','Q03ZS4','NBYTNK','AMGRF5','1E2DJD','1A3HEJ','FJ0YAA','ZVCGS6']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 17
#1.4~1.5
a = ['PZYUR4','O2J0OX','KMQGJQ','RG7BYC','8Q2G59','BLQXV7','L0ZLXK','WDVVLL','6FE43Q','47QGIA','M72HED']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 18
#1.5~1.6
a = ['YXAKR4','YGHZ0X','1EZAFG']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 19
#1.6~1.7
a = ['9BO2S9','RKP5AP','CRVF1Z','HRIQ4G','ID1L6P','MWL4TG']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 20
#1.7~1.8
a = ['I8ST7N','PNE6WR']
for i in a : 
    df_org.loc[df_org['특송업체부호'] == i , '특송업체부호'] = 21

# %%
a = ['D','E','C']
for i in a : 
    df_org.loc[df_org['수입통관계획코드'] == i , '수입통관계획코드'] = 10
a = ['D','E']
for i in a : 
    df_org.loc[df_org['수입신고구분코드'] == i , '수입신고구분코드'] = 11

# %%
#0.5~0.6
a = [94,87,91]
for i in a : 
    df_org.loc[df_org['수입거래구분코드'] == i , '수입거래구분코드'] = 100
#1.2~1.3
a = [85,86]
for i in a : 
    df_org.loc[df_org['수입거래구분코드'] == i , '수입거래구분코드'] = 101
#1.3~1.39
a = [92,21]
for i in a : 
    df_org.loc[df_org['수입거래구분코드'] == i , '수입거래구분코드'] = 102
#1.39~1.49
a = [89,93,96,84,88,80]
for i in a : 
    df_org.loc[df_org['수입거래구분코드'] == i , '수입거래구분코드'] = 103
#1.49~1.6
a = [29,83]
for i in a : 
    df_org.loc[df_org['수입거래구분코드'] == i , '수입거래구분코드'] = 104

# %%
#2.28
a = [12,13]
for i in a : 
    df_org.loc[df_org['수입종류코드'] == i , '수입종류코드'] = 100
#2.69
a = [15,23,27]
for i in a : 
    df_org.loc[df_org['수입종류코드'] == i , '수입종류코드'] = 101

# %%
#0.59~0.61
a = [14,0]
for i in a : 
    df_org.loc[df_org['징수형태코드'] == i , '징수형태코드'] = 100
#0.43~0.49
a = [43,18]
for i in a : 
    df_org.loc[df_org['징수형태코드'] == i , '징수형태코드'] = 101

# %%
#0.92~0.97
a = [30,50]
for i in a : 
    df_org.loc[df_org['운송수단유형코드'] == i , '운송수단유형코드'] = 100
# 1.69~1.8
a = [20,90]
for i in a : 
    df_org.loc[df_org['운송수단유형코드'] == i , '운송수단유형코드'] = 101

# %%
# 0.25~0.3,  counts > 300
a = ['CN','JP','CA']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 100
# 0.25~0.3,  counts < 300
a = ['RO','OM','BH','UG']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 101
# 0.25~0.3,  counts < 20
a = ['BH','UG']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 102
# 0.3~0.35,  counts > 1000
a = ['VN','TH']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 103
# 0.3~0.35,  counts < 1000
a = ['TW','NL','KR','ID','BE','MY','PH','AU','AE']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 104
# 0.3~0.35,  counts < 200
a = ['TR','NZ']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 105
# 0.3~0.35,  counts < 100
a = ['IL','MM','HU','GR']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 106
# 0.3~0.35,  counts < 10
a = ['KW','LV','UZ','PR','KG','HR','MG','DO','NG']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 107
# 0.35~0.4,  counts > 300
a = ['DE','HK','IT','SG','IN']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 108
# 0.35~0.4,  93 < counts < 260
a = ['SE','MX','CH','KH','CL','FI']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 109
# 0.35~0.4,  counts < 80
a = ['BR','PA','SI','PL']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 110
# 0.35~0.4,  counts < 40
a = ['GU','PT','EC','CZ','SN','ET','LU','PE']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 111
# 0.35~0.4,  counts < 20
a = ['ZZ','LK']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 112
# 0.4~0.45,  counts < 1500
a = ['GB','ES','MX']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 113
# 0.4~0.45,  counts < 100
a = ['PK','BD','AT']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 114
# 0.4~0.45,  counts < 30
a = ['EG','PE','MO','EE','MN']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 115
# 0.45~0.5,  counts < 30
a = ['GN','ZA','PY']
for i in a : 
    df_org.loc[df_org['적출국가코드'] == i , '적출국가코드'] = 116

# %%
# 0.2~0.25,  counts < 800
a = [27.0, 3.9, 5.2, 20.0]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 100
# 0.2~0.25,  counts < 200
a = [5.6,9.1,377.3,36.0]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 101
# 0.28~0.3,  counts < 1500
a = [5.0,10.0, 1.3]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 102
# 0.25~0.28,  counts < 1500
a = [5.2,14.0,377.3,44.5]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 103
# 0.3~0.35,  1000<counts < 6000
a = [13.0,3.2,4.8]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 104
# 0.3~0.32,  counts < 450
a = [4.0, 3.0, 45.0, 30.0]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 105
# 0.3~0.32,  counts < 100
a = [16.0,1.0,0.5,0.8,3.6,9.6]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 106
# 0.32~0.34,  counts < 2500
a = [3.2,4.8]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 107
# 0.32~0.34,  counts < 300
a = [5.5, 40.0]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 108
# 0.32~0.34,  counts < 50
a = [21.3, 7.5]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 109
# 0.333333
a = [21.0, 0.6, 15.7, 554.8, 360.0, 6.4, 7.2, 1.1, 11.7]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 110
# 0.34~0.36   counts < 300
a = [4.9, 45.0, 6.0, 135.0, 30.0, 40.0, 26.6, 2.0, 7.8]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 111
# 0.34~0.36   counts < 50
a = [13.5, 754.3, 6.3, 22.0]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 112
# 0.36~0.38   counts < 80
a = [2.2, 57.5, 8.1, 1.2, 5.4]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 113
# 0.375
a = [800.3, 11.0, 513.6, 2.1]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 114
# 0.38~0.4
a = [50.0, 270.0, 15.0]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 115
# 0.42~0.44
a = [243.0, 18.0]
for i in a : 
    df_org.loc[df_org['관세율'] == i , '관세율'] = 116
